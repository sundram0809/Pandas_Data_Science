# %%
import pandas as pd

# %%
import pandas as pd

# %%
import pandas as pd
country = ['India','Pakistan','USA','Nepal','Srilanka']
number=[1,2,3,4,5]
pd.Series(country,index=number)
# Out:
# 1       India
# 2    Pakistan
# 3         USA
# 4       Nepal
# 5    Srilanka
# dtype: object
