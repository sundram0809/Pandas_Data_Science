# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("titanic.csv")
df["Name"]

# %%
df["Name"].str.upper()
df["Name"].str.capitalize() #suru ka captital kar deta hai
df["Name"].str.title() #saabhi ka pahla captital ho jata hai
df["Name"].str.len().max()
df[df["Name"].str.len()==82]["Name"]

#strip
"             nitish         ".strip()

# %%
df["last"]=df["Name"].str.split(',').str.get(0)
df

# %%
#df["Name"].str.split(",").str.get(1).str.strip(),str.split(" ",expand=True)
df["first_name"]=df["Name"].str.split(" ,").str.get(0).str.split(" ,").str.get(0).str.split().str.get(1)
df

# %%
df["first_name"].value_counts()

# %%
df["last"]
df[df["last"].str.startswith("A")]

# %%
df[df["last"].str.endswith("A")]
df[df["last"].str.isdigit()]

# %%
#contains

df[df["Name"].str.contains("john",case=False)]
