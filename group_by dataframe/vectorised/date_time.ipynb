# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
pd.Timestamp("2023/12/03")
# Out:
# Timestamp('2023-12-03 00:00:00')

# %%
pd.Timestamp("2023-12-03")
# Out:
# Timestamp('2023-12-03 00:00:00')
