# %%
import pandas as pd

# %%
import pandas as pd

# %%
#string
import pandas as pd
country = ['India','Pakistan','USA','Nepal','Srilanka']
number=[1,2,3,4,5]
pd.Series(country,index=number)

# %%
run =[12,3,4,55,667,88]
run_series=pd.Series(run)
run_series

# %%
#custom index
marks =[12,44,55,66,98]
subject=["maths","science","physics","sst","hindi"]
pd.Series(subject,index=marks)

# %%
#setting  a name
marks =[12,44,55,66,98]
subject=["maths","science","physics","sst","hindi"]
pd.Series(marks,index=subject,name="sundrm ke marks hai ")

# %%
#dict in seires

marks={
    "maths":12,
    "sicence":13,
    "physics":20
    #keys or index ban jata hai

}
marks_series=pd.Series(marks,name="sundram ji ke pass")
marks_series

# %%
#

# %% [markdown]
# series attributes

# %%
#size
marks_series.size

# %%
#dtype
marks_series.dtype

# %%
#name

 
marks_series.name

# %%
marks_series.is_unique

# %%
#index

marks_series.index

# %%
run_series.index

# %%
marks_series.values

# %%
run_series.values

# %% [markdown]
# **series using read_csv**

# %%
import pandas as pd
subs=pd.read_csv("subs.csv").squeeze()#function hogya hai series ka
#squeeze dataframe ko series btata hai ji
subs

# %%
pd.read_csv("kohli_ipl.csv").squeeze()

# %%
vk=pd.read_csv("kohli_ipl.csv",index_col="match_no").squeeze()
vk

# %%
mv=pd.read_csv("bollywood.csv",index_col="movie").squeeze()
mv

# %% [markdown]
# **series methods**

# %%
#head and tails
subs.head()
#starting data

# %%
subs.head(10)

# %%
vk.head()

# %%
vk.tail(9)
#last data provide

# %%
#sample
#random row provide
mv.sample(5)

# %%
#value count

mv

# %%
mv.value_counts()
#specific actor ka frequency btana

# %%
#sort_value

vk.sort_values()
#kam no. run wala ascending

# %%
vk.sort_values(ascending=False)
#decesending order

# %%
vk.sort_values(ascending=False).values[0]

# %%
#sort_value inplace

#permanant change in dataset

#vk.sort_values(inplace=True)

# %%
vk

# %%
mv

# %%
mv.sort_index()

# %%
mv.sort_index(inplace=True)
#permant change in dtaset
mv

# %% [markdown]
# **maths series mthod**

# %%
#count
vk.count()

# %%
#sum-> product

subs.sum()

# %%
subs.product()

# %%
#mean->mode->median

subs.mean()
print(vk.median())
print(mv.mode())
print(vk.var())

# %%
#min/max

subs.min()
subs.max()

# %%
#describe

vk.describe()
subs.describe()#berief about the dataset

# %% [markdown]
# **series indexing**

# %%
#integer indexing

x=pd.Series([12,13,45,67,90])
x

# %%
x[1]

# %%
#negative indexing

#no negative

#x[-1]

# %%
#slicing
vk[5:16]

# %%
mv[-1::]

# %%
#fancy indexing


vk[[2,5,7,8]]

# %%
mv

# %%
mv["Hum Tumhare Hain Sanam"]

# %% [markdown]
# **editing series**

# %%
marks_series

# %%
marks_series[1]=200

# %%
marks_series

# %%
#what if an index does not exits

marks_series["sst"]=80#write akr skte hai

marks_series

# %%
#slicing
run_series
run_series[2:4]=[19,50]
run_series

# %%
#fancinf indexing

run_series[[1,3,4]]=[1,1,1]
run_series

# %%
mv

# %% [markdown]
# **series with python funtionalities**

# %%
print(type(subs))
print(len(subs))
print(dir(subs))

# %%
#type converstion
marks_series

# %%
list(marks_series)

# %%
dict(marks_series)

# %%
"Alia Bhatt" in mv.values

# %%
mv

# %%
"Hrithik Roshan" in mv
#ye index pe search karega ji

# %%
"Hrithik Roshan" in mv.values
#ye values pe search kareha ji

# %%
#looping

for i in mv:
 print(i)

# %%
#aritematics operators

100+marks_series

# %%
#relational operator

vk

vk>=50

# %%
#find o. of 50 and 100 scored by kohli

vk[vk>=50].size

# %%
#ducks
vk[vk==0].size

# %%
subs[subs>200].size

# %%
#movies have done more than 20 movies

nums=mv.value_counts()

nums[nums>20]

# %% [markdown]
# **plotting graphs on series**

# %%
subs.plot()

# %%
top=mv.value_counts().head(20)
top

# %%
top.plot(kind="pie")

# %%
top.plot(kind="bar")

# %%
#some more important series methods

#astype
#between
#clip

# %%
subs

# %%
#astype
import sys
sys.getsizeof(vk)

# %%
ty=vk.astype("int16")


sys.getsizeof(ty)
print(ty)

# %%
#between
vk[vk.between(51,99)].size

# %%
#clip

subs

# %%
subs.clip(100,200)

#100 se ko 100 bana deta hi 
#200 se jada wale ko 200 bana deta hai
#100-200 se ander wale ko same rakhta haui

# %%
#drop_duplicate
temp=pd.Series([1,2,3,4,1,2,3])
temp

# %%
temp.drop_duplicates()

# %%
#isnull

vk.isnull()

# %%
#dropna

temp.dropna()

# %%
#isin

vk

# %%
vk[vk.isin([49,99])]

# %%
#apply

mv

# %%
import numpy as np
import pandas as pd

mv.apply(lambda x: x.split()[0].upper())

# %%
subs

# %%
subs.apply(lambda x: "good day"  if x >subs.mean() else "bad day")

# %%
#copy

vk

# %%
new= vk.head()
new

# %%
new.copy
