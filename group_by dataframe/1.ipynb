# %%
import numpy as np
import pandas as pd

# %%
dl=pd.read_csv("deliveries.csv")
dl
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
mv=pd.read_csv("imdb-top-1000.csv")
mv
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
mv.head(1)

# %%
genres=mv.groupby("Genre")

# %%
genres.sum()

# %%
genres.min()

# %%
genres.min()

# %%
mv.groupby("Genre").sum()["Gross"].sort_values(ascending=False).head(3)

# %%
#find the genrre with highest thwe imbd
mv.groupby("Genre")["IMDB_Rating"].mean().sort_values(ascending=False).head(1)

# %%
#find the highst the direction on the basis of thw vote 

mv.groupby("Director")["No_of_Votes"].sum().sort_values(ascending=False).head(2)

# %%
#hight rated imbd based
mv.groupby("IMDB_Rating")

# %%
#highst no. of movies done by actor
mv.groupby("Star1")["Series_Title"].count().sort_values(ascending=False)

# %%
genres.get_group("Horror")

# %%
genres.get_group("Fantasy")

# %%
genres.groups

# %%
genres.describe()

# %%
genres.nunique()

# %%
genres.sum()

# %%
genres.head(5)

# %%
im

# %%
genres.sum()

# %%
#passing with dige

genres.agg(
    {
        "runtime":"mean",
        "IMDB_Rating":"mean"
        

    }
)

# %%
mv.agg(["max","min"])
# Out:
#                     Series_Title Released_Year  Runtime    Genre  IMDB_Rating  \
# max  Ôkami kodomo no Ame to Yuki            PG      321  Western          9.3
# min         (500) Days of Summer          1920       45   Action          7.6
#
#              Director             Star1  No_of_Votes        Gross  Metascore
# max  Ömer Faruk Sorak  Ömer Faruk Sorak      2343110  936662225.0      100.0
# min        Aamir Khan        Aamir Khan        25088       1305.0       28.0

# %%
genres.nunique()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...

# %%
genres.sum()
# Out:
#                                                 Series_Title  \
# Genre
# Action     The Dark KnightThe Lord of the Rings: The Retu...
# Adventure  InterstellarBack to the FutureInglourious Bast...
# Animation  Sen to Chihiro no kamikakushiThe Lion KingHota...
# Biography  Schindler's ListGoodfellasHamiltonThe Intoucha...
# Comedy     GisaengchungLa vita è bellaModern TimesCity Li...
# Crime      The GodfatherThe Godfather: Part II12 Angry Me...
# Drama      The Shawshank RedemptionFight ClubForrest Gump...
# Family     E.T. the Extra-TerrestrialWilly Wonka & the Ch...
# Fantasy                Das Cabinet des Dr. CaligariNosferatu
# Film-Noir   The Third ManThe Maltese FalconShadow of a Doubt
# Horror     PsychoAlienThe ThingThe ExorcistNight of the L...
# Mystery    MementoRear WindowVertigoShutter IslandKahaani...
# Thriller                                     Wait Until Dark
# Western    Il buono, il brutto, il cattivoOnce Upon a Tim...
#
# ...

# %%
#agg   passig with the dict
genres.agg(
    {
       "Runtime":"mean",
       "IMDB_Rating":"mean",
       "Gross":"mean",
       "No_of_Votes":"sum"
       

        
    }
)
# Out:
#               Runtime  IMDB_Rating         Gross  No_of_Votes
# Genre
# Action     129.046512     7.949419  1.897224e+08     72282412
# Adventure  134.111111     7.937500  1.319017e+08     22576163
# Animation   99.585366     7.930488  1.784326e+08     21978630
# Biography  136.022727     7.938636  9.404952e+07     24006844
# Comedy     112.129032     7.901290  1.010572e+08     27620327
# Crime      126.392523     8.016822  7.899656e+07     33533615
# Drama      124.737024     7.957439  1.225259e+08     61367304
# Family     107.500000     7.800000  2.195553e+08       551221
# Fantasy     85.000000     8.000000  3.913633e+08       146222
# Film-Noir  104.000000     7.966667  4.197018e+07       367215
# Horror     102.090909     7.909091  9.405902e+07      3742556
# Mystery    119.083333     7.975000  1.047014e+08      4203004
# Thriller   108.000000     7.800000  1.755074e+07        27733
# Western    148.250000     8.350000  1.455538e+07      1289665

# %%
genres.agg([min,max])
#passing with list
# Out:
# C:\Users\Sundram\AppData\Local\Temp\ipykernel_16276\107228508.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   genres.agg([min,max])
# C:\Users\Sundram\AppData\Local\Temp\ipykernel_16276\107228508.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   genres.agg([min,max])
#                               Series_Title  \
#                                        min
# Genre
# Action                                 300
# Adventure            2001: A Space Odyssey
# Animation                            Akira
# Biography                 12 Years a Slave
# Comedy                (500) Days of Summer
# ...

# %%
genres.agg(
    {
        "Runtime":["max","min","sum"],
        "No_of_Votes":"max",
        "Metascore":"min"
        
        
        

    }
)
# Out:
#           Runtime             No_of_Votes Metascore
#               max  min    sum         max       min
# Genre
# Action        321   45  22196     2303232      33.0
# Adventure     228   88   9656     1512360      41.0
# Animation     137   71   8166      999790      61.0
# Biography     209   93  11970     1213505      48.0
# Comedy        188   68  17380      939631      45.0
# Crime         229   80  13524     1826188      47.0
# Drama         242   64  36049     2343110      28.0
# Family        115  100    215      372490      67.0
# Fantasy        94   76    170       88794       NaN
# Film-Noir     108  100    312      158731      94.0
# Horror        122   71   1123      787806      46.0
# Mystery       138   96   1429     1129894      52.0
# Thriller      108  108    108       27733      81.0
# Western       165  132    593      688390      69.0

# %%
pl=pd.read_csv("deliveries.csv")
pl
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
pl.groupby("batsman")["batsman_runs"].sum().sort_values(ascending=False).head(10)
# Out:
# batsman
# V Kohli           5434
# SK Raina          5415
# RG Sharma         4914
# DA Warner         4741
# S Dhawan          4632
# CH Gayle          4560
# MS Dhoni          4477
# RV Uthappa        4446
# AB de Villiers    4428
# G Gambhir         4223
# Name: batsman_runs, dtype: int64

# %%
six=pl[pl["batsman_runs"]==6]

six.groupby("batsman")["batsman"].count().sort_values(ascending=False).head(5)
# Out:
# batsman
# CH Gayle          327
# AB de Villiers    214
# MS Dhoni          207
# SK Raina          195
# RG Sharma         194
# Name: batsman, dtype: int64
